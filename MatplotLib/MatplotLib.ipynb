# %%
# Random
x = np.random.rand(50)
y = np.random.randn(50) # Normal distribution

df = pd.DataFrame(np.random.randn(1000), columns=['Data'], index = pd.date_range('2024-08-27', periods=1000))

plt.scatter(x,y) # 1. Scatter plot

# --------------------------------------------------------------------------------------------------------
# 2. Line plot
plt.plot(x,y1, color='purple', marker='o', linestyle='--', linewidth=2, markersize=10, label='Line y1 as tata motors')
plt.plot(x,y2, color='orange', marker='o', linestyle='--', linewidth=2, markersize=10, label='Line y2 as tata power')

plt.title('Multiple lines in one plot')
plt.xlabel('Days')
plt.ylabel('stock prices')
plt.grid()

plt.legend() # shows the meta data information that we provided to plot
plt.show()
# --------------------------------------------------------------------------------------------------------

np.linspace(0,10, 100) # Generate 100 data points between 1-10

plt.figure() #initializing a page to make plot

# --------------------------------------------------------------------------------------------------------
# Multiple plots
plt.figure()
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))

plt.subplot(2,2,2)
plt.plot(x, np.cos(x))

plt.subplot(2,2,3)
plt.plot(x, np.tan(x))

plt.subplot(2,2,4)
plt.plot(x, np.sin(x+1))

plt.show()
# --------------------------------------------------------------------------------------------------------

# --------------------------------------------------------------------------------------------------------
# Limit axis
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
# --------------------------------------------------------------------------------------------------------


# --------------------------------------------------------------------------------------------------------
# Histogram (For Frequency of distribution)
d1 = np.random.normal(0,1,5000)
d2 = np.random.normal(3,2,5000)

plt.hist([d1,d2], bins=20, color=['r','b'], label=['dist1', 'dist2'])

plt.xlabel('Numbers / Data')
plt.ylabel('Frequency')

plt.legend()
plt.show()
# --------------------------------------------------------------------------------------------------------

plt.scatter(x,y, c='r', marker='X') # Scatter plot
plt.bar(x,y, color='r') # vertical bar
plt.barh(x,y, color='b') # horizontal bar 
plt.pie(quantity, labels=attribute, autopct='%1.1f%%', explode=explode, shadow=True) # Pie plot

# --------------------------------------------------------------------------------------------------------
# 3D plot
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x,y,z, c='red')
# --------------------------------------------------------------------------------------------------------

# For outliers
data.boxplot(column='Balance') # Box plt
data.violinplot(data['Balance']) # Violin plt
plt.stackplot(years, category1, category2, category3, labels=["category1", "category2", "category3"], colors=['blue','red','yellow'])
# Area plot '^

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Supress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
x = np.random.rand(50)

# %%
x
# Out:
# array([0.36065447, 0.00630216, 0.94624707, 0.32664851, 0.2756474 ,
#        0.85821886, 0.66738185, 0.55764428, 0.18430208, 0.37036159,
#        0.07712756, 0.09053984, 0.77705198, 0.05013972, 0.92871362,
#        0.17149639, 0.03142247, 0.76281082, 0.56435492, 0.66128907,
#        0.87096383, 0.77784112, 0.09800614, 0.14785639, 0.56423735,
#        0.91169968, 0.24045772, 0.93420448, 0.37939781, 0.89755944,
#        0.30065067, 0.15158362, 0.29879448, 0.98489204, 0.86582548,
#        0.88516546, 0.73169812, 0.47510501, 0.08658552, 0.38395121,
#        0.0519343 , 0.23562026, 0.15727407, 0.03771743, 0.22621079,
#        0.58823004, 0.12500154, 0.32720214, 0.07521182, 0.73328561])

# %%
# Normal distribution
np.random.randn(50)
# Out:
# array([-0.57059146,  1.22017441, -1.00183926,  1.53746013, -0.23374549,
#         0.5040731 ,  0.96214561,  0.44557014,  0.96212663, -1.17521961,
#         0.64918098,  1.05899439,  1.1888405 , -0.57326737, -0.31727156,
#         0.4512829 ,  0.4579824 ,  0.10907085,  0.2748482 , -0.78926461,
#         1.35754713, -0.58253201, -2.72095702, -0.11036342,  0.02368549,
#         0.99537617, -0.11187743,  0.99047516, -2.25507806, -0.89803167,
#        -1.86759579, -1.1562084 , -0.23747748,  0.43823268,  0.13620874,
#        -1.16927092,  1.19627698, -0.5053415 ,  0.1790954 , -2.40631693,
#         1.12200209, -0.56600604,  0.80138843,  1.68628831,  1.44498043,
#        -0.02519944, -1.45262621, -0.93409402,  1.71453221,  1.03318354])

# %%
df = pd.DataFrame(np.random.randn(1000), columns=['Data'], index = pd.date_range('2024-08-27', periods=1000))

# %%
df
# Out:
#                 Data
# 2024-08-27  1.006249
# 2024-08-28 -0.002482
# 2024-08-29 -0.675564
# 2024-08-30  0.997753
# 2024-08-31 -0.128011
# ...              ...
# 2027-05-19 -1.381174
# 2027-05-20  1.463750
# 2027-05-21  1.703379
# 2027-05-22  0.983020
# 2027-05-23 -1.580950
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20,8))
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.36065447, 0.00630216, 0.94624707, 0.32664851, 0.2756474 ,
#        0.85821886, 0.66738185, 0.55764428, 0.18430208, 0.37036159,
#        0.07712756, 0.09053984, 0.77705198, 0.05013972, 0.92871362,
#        0.17149639, 0.03142247, 0.76281082, 0.56435492, 0.66128907,
#        0.87096383, 0.77784112, 0.09800614, 0.14785639, 0.56423735,
#        0.91169968, 0.24045772, 0.93420448, 0.37939781, 0.89755944,
#        0.30065067, 0.15158362, 0.29879448, 0.98489204, 0.86582548,
#        0.88516546, 0.73169812, 0.47510501, 0.08658552, 0.38395121,
#        0.0519343 , 0.23562026, 0.15727407, 0.03771743, 0.22621079,
#        0.58823004, 0.12500154, 0.32720214, 0.07521182, 0.73328561])

# %%
y = np.random.randn(50)
y
# Out:
# array([ 0.13515953,  1.28807088, -0.1604686 , -0.59097147, -1.37928537,
#        -3.43057314, -1.48374027, -0.15940174,  1.78216355, -0.75969126,
#        -2.17400385,  1.84763844,  0.64105206,  1.54560357, -1.27809999,
#        -1.46589915, -0.34332173, -0.66984496, -0.40340764,  2.30233255,
#         0.78990105,  0.6744464 ,  0.17468406,  0.55293138, -1.24598204,
#         1.69290467, -1.28399556, -0.14566699,  0.58202753, -0.04763582,
#         0.77280357, -0.80025989, -0.84043228, -0.60375038,  1.20649139,
#         0.69697947, -0.39664771, -0.03927656,  2.19310203,  0.62488592,
#         0.07732143,  0.43923307, -1.05622425,  0.88064077,  1.01005069,
#        -0.2199703 ,  1.97580052, -0.91729438,  0.01985128, -1.69986248])

# %%
plt.scatter(x,y)

# %% [markdown]
# ## Line plot

# %%
# Line plot
# To depict the trend between variables
# x-axis mostly contains date-time column

x = [1,2,3,4,5] # days
y = [5,2,7,8,1] # price

plt.plot(x,y)

# %%
plt.plot(x,y, color='red', marker='o', linestyle='--', linewidth=4, markersize=20)
plt.title('Line chart to understand the syntax')
plt.xlabel('Day intervals')
plt.ylabel('Price')
plt.grid()
plt.show() # Remove meta data

# %%
x = [1,2,3,4,5]
y1 = [5,2,7,8,1]
y2 = [7,8,3,5,1]

# %%
plt.plot(x,y1, color='purple', marker='o', linestyle='--', linewidth=2, markersize=10, label='Line y1 as tata motors')
plt.plot(x,y2, color='orange', marker='o', linestyle='--', linewidth=2, markersize=10, label='Line y2 as tata power')

plt.title('Multiple lines in one plot')
plt.xlabel('Days')
plt.ylabel('stock prices')
# Out:
# Text(0, 0.5, 'stock prices')

# %%
plt.plot(x,y1, color='purple', marker='o', linestyle='--', linewidth=2, markersize=10, label='Line y1 as tata motors')
plt.plot(x,y2, color='orange', marker='o', linestyle='--', linewidth=2, markersize=10, label='Line y2 as tata power')

plt.title('Multiple lines in one plot')
plt.xlabel('Days')
plt.ylabel('stock prices')

plt.legend() # shows the meta data information that we provided to plot
plt.show()

# %%
x = np.linspace(0,10, 100)

# %%
plt.plot(x, np.sin(x), '.', label='sine')
plt.plot(x, np.cos(x), '.-', label='cosine')

plt.legend()

# %% [markdown]
# ## Multiple plots

# %%
plt.figure() #initializing a page to make plot
plt.subplot(2,1,1)
plt.plot(x, np.sin(x))

plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))

plt.subplot(2,2,2)
plt.plot(x, np.cos(x))

plt.subplot(2,2,3)
plt.plot(x, np.tan(x))

plt.subplot(2,2,4)
plt.plot(x, np.sin(x+1))

plt.show()

# %% [markdown]
# ## Limit the x&y limits

# %%
plt.plot(x, np.sin(x), color='r')

# %%
plt.plot(x, np.sin(x), color='r')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')

plt.title('Applying asthetica')

plt.grid()
plt.show()

# %% [markdown]
# ## Histogram

# %%
data = np.random.rand(50)

# %%
# By default: Bins are 10

plt.hist(data, color='r', bins=20)
plt.xlabel('Data')
plt.ylabel('Frequency of occurance')
# Out:
# Text(0, 0.5, 'Frequency of occurance')

# %%
data
# Out:
# array([0.44033966, 0.1731383 , 0.84315827, 0.57262655, 0.83243489,
#        0.34220336, 0.48110257, 0.63450433, 0.62121373, 0.69871818,
#        0.17257298, 0.08383382, 0.3983045 , 0.31378085, 0.89693005,
#        0.77445028, 0.00655734, 0.83195791, 0.84149024, 0.46698287,
#        0.64272245, 0.90807488, 0.01938786, 0.34369828, 0.09692215,
#        0.6888056 , 0.74032657, 0.36629911, 0.23263064, 0.08577959,
#        0.66591774, 0.43682983, 0.29073678, 0.13812117, 0.75786061,
#        0.7449895 , 0.41646712, 0.84090942, 0.11251718, 0.84166445,
#        0.35184643, 0.7339267 , 0.73916828, 0.97595681, 0.76595053,
#        0.27777139, 0.92553848, 0.53184152, 0.05089416, 0.31932049])

# %%
d1 = np.random.normal(0,1,5000)
d2 = np.random.normal(3,2,5000)

plt.hist([d1,d2], bins=20, color=['r','b'], label=['dist1', 'dist2'])

plt.xlabel('Numbers / Data')
plt.ylabel('Frequency')

plt.legend()
plt.show()

# %% [markdown]
# ## Scatter plot

# %%
x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x,y, c='r', marker='X')

plt.show()

# %% [markdown]
# ## Bar plot

# %%
x = ["a", "b", "c","d"] #name of students
y = [4, 6, 1, 10] #no of days present in the class

plt.bar(x, y, color = 'r') #vertical plot
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x, y, color = 'r') #horizontal plot
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ## Pie chart

# %%
#pie char >> To understand the percent distribution of data

explode = (0.0, 0.0, 0.1)
attribute = ["C", "Python", "Java"]
quantity = [20, 100, 40]

plt.pie(quantity, labels=attribute, autopct='%1.1f%%', explode=explode, shadow=True)
plt.show()

# %% [markdown]
# ## 3D plot

# %%
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x,y,z, c='red')

# %%
data = pd.read_csv("Bank_Churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.scatter(data['Age'],data['Balance'])

# %%
data.plot.scatter(x='Age', y='Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data['Age'])
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Box plot
#
# #### To detect the outliers

# %%
data.boxplot(column='Balance')
# Out:
# <Axes: >

# %% [markdown]
# ## Voilin plot
#
# #### For Outliers

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1cbb6bc8190>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1cbb6c4ef90>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1cbb6c53dd0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1cbb6c49ed0>}

# %% [markdown]
# ## Area plot

# %%
years = [2021, 2018, 2022, 2023, 2017]
category1 = [20, 25, 30, 28, 35]
category2 = [10, 15, 20, 18, 25]
category3 = [5, 8, 10, 9, 15]

plt.stackplot(years, category1, category2, category3, labels=["category1", "category2", "category3"], colors=['blue','red','yellow'])
plt.legend()
plt.show()
