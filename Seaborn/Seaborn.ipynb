# %%
# Seaborn has its own datasets
sns.load_dataset('tips')

# hue: gives the different color shades
# Style: gives different representation of column value
# Both style and hue
sns.relplot(x = 'total_bill', y = 'tip', data=df, style='smoker', hue='time')

# ---------------------------------------------------------------------------------------------------
# Line plot: kind='line'
sns.relplot(x='time', y='value', data=df, kind='line', sort=True)

# Statistics concept: ci=sd
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', ci='sd')

# to remove ci (remove shaded region): estimator=None
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', estimator=None)

# Add hue, style, markers, dashes to Line plot
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', style='region', hue='event', markers=True, dashes=False)
# ---------------------------------------------------------------------------------------------------

# Histogram
sns.histplot(data, bins=30, kde=True)

# Multiple plot: col='col_name'
sns.relplot(x='total_bill', y='tip', data=tips, col='time')

# avoid overlapping: kind='swarn' (For catplot)
sns.catplot(x='total_bill', y='tip', data=tips, kind='swarn')
# kind = box, violin, boxen, swarn

sns.barplot(x = 'day', y = 'total_bill', data = tips) # Bar plot
sns.jointplot(x = 'total_bill', y = 'tip', data = tips) # Joint plot [kind: 'hex', 'reg', 'kde']

# Multiple plots of column with each other
sns.pairplot(tips)
sns.pairplot(tips, hue = 'smoker', palette='coolwarm') # apply hue, and change color

sns.boxplot(data = tips, palette = 'rainbow', orient = 'h') # Change orientation: orient='h'
sns.heatmap(df1.corr(), cmap='coolwarm', annot=True) # Heatmap for CORRELATION in statistics
sns.countplot(x = 'sex', data=df)# Count plot
sns.lmplot(x='total_bill', y='tip', data=df, height=15, aspect=2) # regression plot

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Seaborn provides its own datasets to practice, if there are not appropriately datasets

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# Numerical data plot
# Relplot (Relationship): Options for both categorical and numerical 

# How tip is varying with total bill >> scatter plot
# By default it has scatter plot
sns.relplot(x = 'total_bill', y = 'tip', data=df)

# %%
# Wether he is smoker or not

sns.relplot(x = 'total_bill', y = 'tip', data=df, hue='smoker')

# %%
# Based on size

sns.relplot(x = 'total_bill', y = 'tip', data=df, hue='size')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data=df, style='size')

# %%
sns.relplot(x = 'total_bill', y = 'tip', data=df, style='smoker', hue='time')

# %% [markdown]
# ## Line chart

# %%
#line plot>> to understand the trend in data, a time column/sequence is generally is there  

time = np.arange(500)
val = np.random.randn(500).cumsum()
df = pd.DataFrame({'time': time, 'value': val})
df
# Out:
#      time      value
# 0       0  -2.323260
# 1       1  -2.062073
# 2       2  -2.396603
# 3       3  -2.193071
# 4       4  -2.057974
# ..    ...        ...
# 495   495  30.676507
# 496   496  30.256888
# 497   497  30.457006
# 498   498  31.367116
# 499   499  32.125391
#
# [500 rows x 2 columns]

# %%
sns.relplot(x='time', y='value', data=df, kind='line', sort=True)

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line')

# %%
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', ci='sd')

# %%
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', estimator=None)

# %%
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', style='region')

# %%
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', style='region', hue='event')

# %%
# No dashes
sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', style='region', hue='event', dashes=False)

# %% [markdown]
# ## Multiple subplots

# %%
# Add markers

sns.relplot(x='timepoint', y='signal', data=fmri, kind='line', style='region', hue='event', markers=True)

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 2 subplots

sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips, col='time')

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips, col='size')

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips, col='day')

# %% [markdown]
# ## Categorical plots

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.catplot(x = 'day', y='total_bill', data=tips)

# %%
# AVOID Overlapping

sns.catplot(x='day', y='total_bill', data=tips, kind='swarm')

# %% [markdown]
# ## Box plot for outliers

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='box')

# %%
# Violin

sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'violin')

# %%
#boxen plot is made from box plot
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'boxen')

# %% [markdown]
# ## Bar plot

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Joint plot

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips)

# %%
# with Regression

sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind='reg')

# %%
# More datapoints will have dark shades

sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind='hex')

# %%
# Contour plot: use more in meterological department

sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind='kde')

# %% [markdown]
# ## Relation with all relavent columns

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'smoker')

# %%
sns.pairplot(tips, hue = 'smoker', palette='coolwarm')

# https://seaborn.pydata.org/generated/seaborn.color_palette.html
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %% [markdown]
# ## Change orientation

# %%
sns.boxplot(data = tips, palette = 'rainbow', orient = 'h')
# Out:
# <Axes: >

# %%
df1 = tips[['total_bill', 'tip', 'size']]
df1
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %% [markdown]
# ## Correlation

# %%
df1.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# Heatmap

sns.heatmap(df1.corr(), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
df = sns.load_dataset('tips')
sns.countplot(x = 'sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x='total_bill', y='tip', data=df)

# %%
# Increase height
sns.lmplot(x='total_bill', y='tip', data=df, height=15)

# %%
# Zoom out

sns.lmplot(x='total_bill', y='tip', data=df, height=15, aspect=2)
